# %%
# Import the dependencies.
import random
import pandas as pd
import numpy as np
from citipy import citipy
from config import weather_api_key
import requests
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats= np.random.uniform(-90, 90 , size=2000)
lngs= np.random.uniform(-180, 180 , size =2000 )
lat_lngs= zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates= list(lat_lngs)

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Create a list for holding the cities.
cities=[]
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city= citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities: 
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 744

# %%
# Create an empty list to hold the weather data.
city_data= []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count= 1
set_count=1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    try:
        # Parse the JSON and retrieve data.
        city_weather= requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description= city_weather['weather'][0]['description']
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | narsaq
# Processing Record 2 of Set 1 | madimba
# Processing Record 3 of Set 1 | lompoc
# Processing Record 4 of Set 1 | namibe
# Processing Record 5 of Set 1 | new norfolk
# Processing Record 6 of Set 1 | kodiak
# Processing Record 7 of Set 1 | georgetown
# Processing Record 8 of Set 1 | mount pleasant
# Processing Record 9 of Set 1 | hambantota
# Processing Record 10 of Set 1 | celestun
# Processing Record 11 of Set 1 | lebu
# Processing Record 12 of Set 1 | atuona
# Processing Record 13 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 14 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 15 of Set 1 | elmadag
# Processing Record 16 of Set 1 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 17 of Set 1 | panzhihua
# Processing Record 18 of Set 1 | mataura
# Processing Record 19 of Set 1 | kapaa
# Processing Record 20 of Set 1 | tiksi
# Processing Record 21 of Set 1 | katsuura
# Processing Record 22 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 23 of Set 1 | rikitea
# Processing Record 24 of Set 1 | kununurra
# Processing Record 25 of Set 1 | bonwapitse
# Processing Record 26 of Set 1 | prince rupert
# Processing Record 27 of Set 1 | jamestown
# Processing Record 28 of Set 1 | marzuq
# Processing Record 29 of Set 1 | bilma
# Processing Record 30 of Set 1 | saint-philippe
# Processing Record 31 of Set 1 | hilo
# Processing Record 32 of Set 1 | haibowan
# City not found. Skipping...
# Processing Record 33 of Set 1 | tautira
# Processing Record 34 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 35 of Set 1 | saint-denis
# Processing Record 36 of Set 1 | busselton
# Processing Record 37 of Set 1 | luchenza
# Processing Record 38 of Set 1 | gravdal
# Processing Record 39 of Set 1 | kalispell
# Processing Record 40 of Set 1 | bjelovar
# Processing Record 41 of Set 1 | hermanus
# Processing Record 42 of Set 1 | barrow
# Processing Record 43 of Set 1 | ushuaia
# Processing Record 44 of Set 1 | along
# Processing Record 45 of Set 1 | pangnirtung
# Processing Record 46 of Set 1 | butaritari
# Processing Record 47 of Set 1 | antalaha
# Processing Record 48 of Set 1 | fort nelson
# Processing Record 49 of Set 1 | hobart
# Processing Record 50 of Set 1 | praia da vitoria
# Processing Record 1 of Set 2 | port blair
# Processing Record 2 of Set 2 | punta arenas
# Processing Record 3 of Set 2 | lavrentiya
# Processing Record 4 of Set 2 | bambari
# Processing Record 5 of Set 2 | vaini
# Processing Record 6 of Set 2 | goderich
# Processing Record 7 of Set 2 | cape town
# Processing Record 8 of Set 2 | norman wells
# Processing Record 9 of Set 2 | severo-kurilsk
# Processing Record 10 of Set 2 | awbari
# Processing Record 11 of Set 2 | kahului
# Processing Record 12 of Set 2 | necochea
# Processing Record 13 of Set 2 | port alfred
# Processing Record 14 of Set 2 | bathsheba
# Processing Record 15 of Set 2 | safwah
# City not found. Skipping...
# Processing Record 16 of Set 2 | tanout
# Processing Record 17 of Set 2 | dauphin
# Processing Record 18 of Set 2 | singaparna
# Processing Record 19 of Set 2 | maumere
# Processing Record 20 of Set 2 | tazovskiy
# Processing Record 21 of Set 2 | albany
# Processing Record 22 of Set 2 | djenne
# Processing Record 23 of Set 2 | angra
# City not found. Skipping...
# Processing Record 24 of Set 2 | komsomolskiy
# Processing Record 25 of Set 2 | east london
# Processing Record 26 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 27 of Set 2 | port elizabeth
# Processing Record 28 of Set 2 | barcelos
# Processing Record 29 of Set 2 | saskylakh
# Processing Record 30 of Set 2 | longyearbyen
# Processing Record 31 of Set 2 | nouadhibou
# Processing Record 32 of Set 2 | yellowknife
# Processing Record 33 of Set 2 | xixiang
# Processing Record 34 of Set 2 | craig
# Processing Record 35 of Set 2 | raymond
# Processing Record 36 of Set 2 | qaanaaq
# Processing Record 37 of Set 2 | manta
# Processing Record 38 of Set 2 | okha
# Processing Record 39 of Set 2 | yomou
# Processing Record 40 of Set 2 | henties bay
# Processing Record 41 of Set 2 | fukue
# Processing Record 42 of Set 2 | cabo san lucas
# Processing Record 43 of Set 2 | salalah
# Processing Record 44 of Set 2 | luanda
# Processing Record 45 of Set 2 | kapit
# Processing Record 46 of Set 2 | kavaratti
# Processing Record 47 of Set 2 | alyangula
# Processing Record 48 of Set 2 | broken hill
# Processing Record 49 of Set 2 | bagdarin
# Processing Record 50 of Set 2 | avarua
# Processing Record 1 of Set 3 | thompson
# Processing Record 2 of Set 3 | bredasdorp
# Processing Record 3 of Set 3 | bonthe
# Processing Record 4 of Set 3 | chuy
# Processing Record 5 of Set 3 | grong
# Processing Record 6 of Set 3 | chokurdakh
# Processing Record 7 of Set 3 | rozkishne
# Processing Record 8 of Set 3 | gachala
# Processing Record 9 of Set 3 | dera bugti
# Processing Record 10 of Set 3 | manyana
# Processing Record 11 of Set 3 | bluff
# Processing Record 12 of Set 3 | dukat
# Processing Record 13 of Set 3 | half moon bay
# Processing Record 14 of Set 3 | acapulco
# Processing Record 15 of Set 3 | loukhi
# Processing Record 16 of Set 3 | balkanabat
# Processing Record 17 of Set 3 | chapais
# Processing Record 18 of Set 3 | davila
# Processing Record 19 of Set 3 | solenzo
# Processing Record 20 of Set 3 | pisco
# Processing Record 21 of Set 3 | yuanping
# Processing Record 22 of Set 3 | yumen
# Processing Record 23 of Set 3 | sao filipe
# Processing Record 24 of Set 3 | bengkulu
# Processing Record 25 of Set 3 | ambodifototra
# City not found. Skipping...
# Processing Record 26 of Set 3 | champerico
# Processing Record 27 of Set 3 | clyde river
# Processing Record 28 of Set 3 | bustamante
# Processing Record 29 of Set 3 | tasiilaq
# Processing Record 30 of Set 3 | longkou
# Processing Record 31 of Set 3 | paamiut
# Processing Record 32 of Set 3 | tuktoyaktuk
# Processing Record 33 of Set 3 | chumikan
# Processing Record 34 of Set 3 | mao
# Processing Record 35 of Set 3 | richards bay
# Processing Record 36 of Set 3 | lugovoy
# Processing Record 37 of Set 3 | maningrida
# Processing Record 38 of Set 3 | lagoa
# Processing Record 39 of Set 3 | kavieng
# Processing Record 40 of Set 3 | lazaro cardenas
# Processing Record 41 of Set 3 | cabedelo
# Processing Record 42 of Set 3 | kingaroy
# Processing Record 43 of Set 3 | mendahara
# City not found. Skipping...
# Processing Record 44 of Set 3 | vao
# Processing Record 45 of Set 3 | castro
# Processing Record 46 of Set 3 | vila velha
# Processing Record 47 of Set 3 | khromtau
# Processing Record 48 of Set 3 | yulara
# Processing Record 49 of Set 3 | miraflores
# Processing Record 50 of Set 3 | belen
# Processing Record 1 of Set 4 | pauini
# Processing Record 2 of Set 4 | formoso do araguaia
# City not found. Skipping...
# Processing Record 3 of Set 4 | krasnoselkup
# Processing Record 4 of Set 4 | saint george
# Processing Record 5 of Set 4 | touros
# Processing Record 6 of Set 4 | constitucion
# Processing Record 7 of Set 4 | tamugan
# Processing Record 8 of Set 4 | riverton
# Processing Record 9 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 10 of Set 4 | cavalcante
# Processing Record 11 of Set 4 | edd
# Processing Record 12 of Set 4 | bambous virieux
# Processing Record 13 of Set 4 | kegayli
# City not found. Skipping...
# Processing Record 14 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 15 of Set 4 | lima
# Processing Record 16 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 17 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 18 of Set 4 | esperance
# Processing Record 19 of Set 4 | itarema
# Processing Record 20 of Set 4 | araouane
# Processing Record 21 of Set 4 | cherskiy
# Processing Record 22 of Set 4 | haines junction
# Processing Record 23 of Set 4 | sirjan
# Processing Record 24 of Set 4 | dingle
# Processing Record 25 of Set 4 | ortakoy
# Processing Record 26 of Set 4 | hasaki
# Processing Record 27 of Set 4 | axim
# Processing Record 28 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 29 of Set 4 | dryden
# Processing Record 30 of Set 4 | jibuti
# Processing Record 31 of Set 4 | san rafael
# Processing Record 32 of Set 4 | boguchany
# Processing Record 33 of Set 4 | sakaraha
# Processing Record 34 of Set 4 | mahebourg
# Processing Record 35 of Set 4 | cidreira
# Processing Record 36 of Set 4 | dianopolis
# City not found. Skipping...
# Processing Record 37 of Set 4 | maragogi
# Processing Record 38 of Set 4 | tilichiki
# Processing Record 39 of Set 4 | obihiro
# Processing Record 40 of Set 4 | san quintin
# Processing Record 41 of Set 4 | matay
# Processing Record 42 of Set 4 | aklavik
# Processing Record 43 of Set 4 | rawson
# Processing Record 44 of Set 4 | torbay
# Processing Record 45 of Set 4 | boguchar
# Processing Record 46 of Set 4 | tahta
# Processing Record 47 of Set 4 | carnarvon
# Processing Record 48 of Set 4 | mattoon
# Processing Record 49 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 50 of Set 4 | antofagasta
# Processing Record 1 of Set 5 | coruripe
# Processing Record 2 of Set 5 | mogadishu
# Processing Record 3 of Set 5 | upernavik
# Processing Record 4 of Set 5 | kloulklubed
# Processing Record 5 of Set 5 | luderitz
# Processing Record 6 of Set 5 | samalaeulu
# City not found. Skipping...
# Processing Record 7 of Set 5 | wonthaggi
# Processing Record 8 of Set 5 | camacha
# Processing Record 9 of Set 5 | ouro preto do oeste
# Processing Record 10 of Set 5 | duz
# City not found. Skipping...
# Processing Record 11 of Set 5 | bonfim
# Processing Record 12 of Set 5 | hirara
# Processing Record 13 of Set 5 | hithadhoo
# Processing Record 14 of Set 5 | villazon
# Processing Record 15 of Set 5 | la romana
# Processing Record 16 of Set 5 | tabou
# Processing Record 17 of Set 5 | san jeronimo
# Processing Record 18 of Set 5 | dubuque
# Processing Record 19 of Set 5 | vung tau
# Processing Record 20 of Set 5 | borgarnes
# Processing Record 21 of Set 5 | suntar
# Processing Record 22 of Set 5 | iquique
# Processing Record 23 of Set 5 | vostok
# Processing Record 24 of Set 5 | moron
# Processing Record 25 of Set 5 | ketchikan
# Processing Record 26 of Set 5 | mar del plata
# Processing Record 27 of Set 5 | garowe
# Processing Record 28 of Set 5 | nara
# Processing Record 29 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 30 of Set 5 | itaqui
# Processing Record 31 of Set 5 | pangody
# Processing Record 32 of Set 5 | maniitsoq
# Processing Record 33 of Set 5 | santa barbara
# Processing Record 34 of Set 5 | gunjur
# Processing Record 35 of Set 5 | albury
# Processing Record 36 of Set 5 | hokota
# Processing Record 37 of Set 5 | puerto ayora
# Processing Record 38 of Set 5 | bacuit
# City not found. Skipping...
# Processing Record 39 of Set 5 | puerto maldonado
# Processing Record 40 of Set 5 | kuandian
# Processing Record 41 of Set 5 | scottsbluff
# Processing Record 42 of Set 5 | north bend
# Processing Record 43 of Set 5 | hovd
# Processing Record 44 of Set 5 | grand gaube
# Processing Record 45 of Set 5 | bethel
# Processing Record 46 of Set 5 | victor harbor
# Processing Record 47 of Set 5 | adrar
# Processing Record 48 of Set 5 | dikson
# Processing Record 49 of Set 5 | severo-yeniseyskiy
# Processing Record 50 of Set 5 | havoysund
# Processing Record 1 of Set 6 | muyezerskiy
# Processing Record 2 of Set 6 | arraial do cabo
# Processing Record 3 of Set 6 | ostrovnoy
# Processing Record 4 of Set 6 | makakilo city
# Processing Record 5 of Set 6 | yar-sale
# Processing Record 6 of Set 6 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 7 of Set 6 | cockburn town
# Processing Record 8 of Set 6 | berlevag
# Processing Record 9 of Set 6 | ihosy
# Processing Record 10 of Set 6 | chikmagalur
# Processing Record 11 of Set 6 | kruisfontein
# Processing Record 12 of Set 6 | afanasyevo
# City not found. Skipping...
# Processing Record 13 of Set 6 | darbhanga
# Processing Record 14 of Set 6 | guerrero negro
# Processing Record 15 of Set 6 | viedma
# Processing Record 16 of Set 6 | coquimbo
# Processing Record 17 of Set 6 | izhma
# Processing Record 18 of Set 6 | colac
# Processing Record 19 of Set 6 | erzin
# Processing Record 20 of Set 6 | mehamn
# Processing Record 21 of Set 6 | airai
# Processing Record 22 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 23 of Set 6 | coahuayana
# Processing Record 24 of Set 6 | saint-pierre
# Processing Record 25 of Set 6 | san patricio
# Processing Record 26 of Set 6 | matai
# Processing Record 27 of Set 6 | stonewall
# Processing Record 28 of Set 6 | alice springs
# Processing Record 29 of Set 6 | royan
# Processing Record 30 of Set 6 | mlalo
# Processing Record 31 of Set 6 | chokwe
# Processing Record 32 of Set 6 | bokoro
# Processing Record 33 of Set 6 | olinda
# Processing Record 34 of Set 6 | statesboro
# Processing Record 35 of Set 6 | ponta delgada
# Processing Record 36 of Set 6 | waynesville
# Processing Record 37 of Set 6 | souillac
# Processing Record 38 of Set 6 | kalmunai
# Processing Record 39 of Set 6 | toamasina
# Processing Record 40 of Set 6 | hearst
# Processing Record 41 of Set 6 | ordzhonikidze
# Processing Record 42 of Set 6 | cap malheureux
# Processing Record 43 of Set 6 | whyalla
# Processing Record 44 of Set 6 | los llanos de aridane
# Processing Record 45 of Set 6 | la ronge
# Processing Record 46 of Set 6 | sulejowek
# Processing Record 47 of Set 6 | te anau
# Processing Record 48 of Set 6 | candawaga
# City not found. Skipping...
# Processing Record 49 of Set 6 | pasighat
# Processing Record 50 of Set 6 | salamanca
# Processing Record 1 of Set 7 | saint-joseph
# Processing Record 2 of Set 7 | saldanha
# Processing Record 3 of Set 7 | kadykchan
# City not found. Skipping...
# Processing Record 4 of Set 7 | linxia
# Processing Record 5 of Set 7 | khani
# Processing Record 6 of Set 7 | sumbuya
# Processing Record 7 of Set 7 | sao felix do xingu
# Processing Record 8 of Set 7 | ponta do sol
# Processing Record 9 of Set 7 | tricase
# Processing Record 10 of Set 7 | pevek
# Processing Record 11 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 12 of Set 7 | provideniya
# Processing Record 13 of Set 7 | juneau
# Processing Record 14 of Set 7 | sao joao da barra
# Processing Record 15 of Set 7 | margate
# Processing Record 16 of Set 7 | cooma
# Processing Record 17 of Set 7 | bubaque
# Processing Record 18 of Set 7 | poliyiros
# City not found. Skipping...
# Processing Record 19 of Set 7 | forestville
# Processing Record 20 of Set 7 | urucara
# Processing Record 21 of Set 7 | sechura
# Processing Record 22 of Set 7 | concarneau
# Processing Record 23 of Set 7 | port augusta
# Processing Record 24 of Set 7 | dhidhdhoo
# Processing Record 25 of Set 7 | kamenka
# Processing Record 26 of Set 7 | hong gai
# Processing Record 27 of Set 7 | prado
# Processing Record 28 of Set 7 | kaitangata
# Processing Record 29 of Set 7 | saint simons
# Processing Record 30 of Set 7 | sulangan
# Processing Record 31 of Set 7 | leshukonskoye
# Processing Record 32 of Set 7 | brigantine
# Processing Record 33 of Set 7 | oyama
# Processing Record 34 of Set 7 | gari
# Processing Record 35 of Set 7 | ozernovskiy
# Processing Record 36 of Set 7 | avezzano
# Processing Record 37 of Set 7 | ancud
# Processing Record 38 of Set 7 | teguise
# Processing Record 39 of Set 7 | kyaukse
# Processing Record 40 of Set 7 | fuerte olimpo
# Processing Record 41 of Set 7 | lasa
# Processing Record 42 of Set 7 | shenjiamen
# Processing Record 43 of Set 7 | yarkovo
# Processing Record 44 of Set 7 | fortuna
# Processing Record 45 of Set 7 | pacific grove
# Processing Record 46 of Set 7 | salinopolis
# Processing Record 47 of Set 7 | ocos
# Processing Record 48 of Set 7 | gebze
# Processing Record 49 of Set 7 | avera
# Processing Record 50 of Set 7 | nuuk
# Processing Record 1 of Set 8 | ilhabela
# Processing Record 2 of Set 8 | orito
# Processing Record 3 of Set 8 | meulaboh
# Processing Record 4 of Set 8 | baoning
# Processing Record 5 of Set 8 | springfield
# Processing Record 6 of Set 8 | tangzhai
# Processing Record 7 of Set 8 | padang
# Processing Record 8 of Set 8 | sovetskiy
# Processing Record 9 of Set 8 | nemuro
# Processing Record 10 of Set 8 | moerai
# Processing Record 11 of Set 8 | maraba
# Processing Record 12 of Set 8 | chiriguana
# Processing Record 13 of Set 8 | saint-francois
# Processing Record 14 of Set 8 | nikolskoye
# Processing Record 15 of Set 8 | nome
# Processing Record 16 of Set 8 | boissevain
# Processing Record 17 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 18 of Set 8 | puerto quijarro
# Processing Record 19 of Set 8 | xichang
# Processing Record 20 of Set 8 | ribeira grande
# Processing Record 21 of Set 8 | bogorodskoye
# Processing Record 22 of Set 8 | licheng
# Processing Record 23 of Set 8 | iqaluit
# Processing Record 24 of Set 8 | manama
# Processing Record 25 of Set 8 | ilulissat
# Processing Record 26 of Set 8 | anadyr
# Processing Record 27 of Set 8 | zyryanka
# Processing Record 28 of Set 8 | ahumada
# City not found. Skipping...
# Processing Record 29 of Set 8 | aguimes
# Processing Record 30 of Set 8 | tocopilla
# Processing Record 31 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 32 of Set 8 | littleton
# Processing Record 33 of Set 8 | bairiki
# Processing Record 34 of Set 8 | anqing
# Processing Record 35 of Set 8 | boa vista
# Processing Record 36 of Set 8 | hervey bay
# Processing Record 37 of Set 8 | tuatapere
# Processing Record 38 of Set 8 | vallenar
# Processing Record 39 of Set 8 | keuruu
# Processing Record 40 of Set 8 | varhaug
# Processing Record 41 of Set 8 | kieta
# Processing Record 42 of Set 8 | ouallam
# Processing Record 43 of Set 8 | aksarka
# Processing Record 44 of Set 8 | olafsvik
# Processing Record 45 of Set 8 | coihaique
# Processing Record 46 of Set 8 | esmeraldas
# Processing Record 47 of Set 8 | meyungs
# City not found. Skipping...
# Processing Record 48 of Set 8 | yacuiba
# Processing Record 49 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 50 of Set 8 | obregon
# Processing Record 1 of Set 9 | bulgan
# Processing Record 2 of Set 9 | jumla
# Processing Record 3 of Set 9 | geraldton
# Processing Record 4 of Set 9 | lishu
# Processing Record 5 of Set 9 | cartagena del chaira
# Processing Record 6 of Set 9 | alihe
# Processing Record 7 of Set 9 | yavatmal
# Processing Record 8 of Set 9 | bismarck
# Processing Record 9 of Set 9 | brumunddal
# Processing Record 10 of Set 9 | juli
# Processing Record 11 of Set 9 | zhigansk
# Processing Record 12 of Set 9 | gualaquiza
# Processing Record 13 of Set 9 | khatanga
# Processing Record 14 of Set 9 | sivas
# Processing Record 15 of Set 9 | naryan-mar
# Processing Record 16 of Set 9 | shimoda
# Processing Record 17 of Set 9 | mayya
# Processing Record 18 of Set 9 | mokhsogollokh
# Processing Record 19 of Set 9 | port lincoln
# Processing Record 20 of Set 9 | malindi
# Processing Record 21 of Set 9 | chimore
# Processing Record 22 of Set 9 | arlit
# Processing Record 23 of Set 9 | sorong
# Processing Record 24 of Set 9 | eyl
# Processing Record 25 of Set 9 | bend
# Processing Record 26 of Set 9 | karaul
# City not found. Skipping...
# Processing Record 27 of Set 9 | shellbrook
# Processing Record 28 of Set 9 | pula
# Processing Record 29 of Set 9 | klyuchi
# Processing Record 30 of Set 9 | choucheng
# City not found. Skipping...
# Processing Record 31 of Set 9 | port hardy
# Processing Record 32 of Set 9 | weilburg
# Processing Record 33 of Set 9 | manaure
# Processing Record 34 of Set 9 | sorvag
# City not found. Skipping...
# Processing Record 35 of Set 9 | wazzan
# City not found. Skipping...
# Processing Record 36 of Set 9 | charlestown
# Processing Record 37 of Set 9 | sitka
# Processing Record 38 of Set 9 | campbell river
# Processing Record 39 of Set 9 | hamilton
# Processing Record 40 of Set 9 | areka
# Processing Record 41 of Set 9 | aktau
# Processing Record 42 of Set 9 | pontianak
# Processing Record 43 of Set 9 | faanui
# Processing Record 44 of Set 9 | alta floresta
# Processing Record 45 of Set 9 | kibala
# Processing Record 46 of Set 9 | talnakh
# Processing Record 47 of Set 9 | jacareacanga
# Processing Record 48 of Set 9 | bambanglipuro
# Processing Record 49 of Set 9 | le vauclin
# Processing Record 50 of Set 9 | ixtapa
# Processing Record 1 of Set 10 | santa pola
# Processing Record 2 of Set 10 | sinkat
# City not found. Skipping...
# Processing Record 3 of Set 10 | javanrud
# Processing Record 4 of Set 10 | grand-santi
# Processing Record 5 of Set 10 | phalodi
# Processing Record 6 of Set 10 | turinsk
# Processing Record 7 of Set 10 | iskateley
# Processing Record 8 of Set 10 | halalo
# City not found. Skipping...
# Processing Record 9 of Set 10 | poum
# Processing Record 10 of Set 10 | banmo
# City not found. Skipping...
# Processing Record 11 of Set 10 | san ramon
# Processing Record 12 of Set 10 | vardo
# Processing Record 13 of Set 10 | uyuni
# Processing Record 14 of Set 10 | falealupo
# City not found. Skipping...
# Processing Record 15 of Set 10 | madingou
# Processing Record 16 of Set 10 | magdagachi
# Processing Record 17 of Set 10 | sinnamary
# Processing Record 18 of Set 10 | asau
# Processing Record 19 of Set 10 | praia
# Processing Record 20 of Set 10 | shubarshi
# Processing Record 21 of Set 10 | cam ranh
# Processing Record 22 of Set 10 | petauke
# Processing Record 23 of Set 10 | waipawa
# Processing Record 24 of Set 10 | morondava
# Processing Record 25 of Set 10 | sevenoaks
# Processing Record 26 of Set 10 | namie
# Processing Record 27 of Set 10 | victoria
# Processing Record 28 of Set 10 | samarai
# Processing Record 29 of Set 10 | ballina
# Processing Record 30 of Set 10 | inuvik
# Processing Record 31 of Set 10 | lorengau
# Processing Record 32 of Set 10 | raga
# Processing Record 33 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 34 of Set 10 | mount isa
# Processing Record 35 of Set 10 | kapuskasing
# Processing Record 36 of Set 10 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 37 of Set 10 | santa isabel do rio negro
# Processing Record 38 of Set 10 | lethem
# Processing Record 39 of Set 10 | parvatsar
# Processing Record 40 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 41 of Set 10 | nanortalik
# Processing Record 42 of Set 10 | bennington
# Processing Record 43 of Set 10 | talavera de la reina
# Processing Record 44 of Set 10 | florida
# Processing Record 45 of Set 10 | honiara
# Processing Record 46 of Set 10 | tawkar
# City not found. Skipping...
# Processing Record 47 of Set 10 | buchanan
# Processing Record 48 of Set 10 | ocampo
# Processing Record 49 of Set 10 | sampang
# Processing Record 50 of Set 10 | klaksvik
# Processing Record 1 of Set 11 | gucheng
# Processing Record 2 of Set 11 | krasnorechenskiy
# Processing Record 3 of Set 11 | umm lajj
# Processing Record 4 of Set 11 | asyut
# Processing Record 5 of Set 11 | macenta
# Processing Record 6 of Set 11 | yingzhong
# City not found. Skipping...
# Processing Record 7 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 8 of Set 11 | svetlogorsk
# Processing Record 9 of Set 11 | kutum
# Processing Record 10 of Set 11 | san cristobal cucho
# Processing Record 11 of Set 11 | banamba
# Processing Record 12 of Set 11 | evanston
# Processing Record 13 of Set 11 | ternate
# Processing Record 14 of Set 11 | yoichi
# Processing Record 15 of Set 11 | fort beaufort
# Processing Record 16 of Set 11 | belaya gora
# Processing Record 17 of Set 11 | namatanai
# Processing Record 18 of Set 11 | matara
# Processing Record 19 of Set 11 | smidovich
# Processing Record 20 of Set 11 | paita
# Processing Record 21 of Set 11 | mbandaka
# Processing Record 22 of Set 11 | staryy nadym
# Processing Record 23 of Set 11 | koupela
# Processing Record 24 of Set 11 | ushtobe
# Processing Record 25 of Set 11 | babanusah
# City not found. Skipping...
# Processing Record 26 of Set 11 | kumluca
# Processing Record 27 of Set 11 | turukhansk
# Processing Record 28 of Set 11 | bridlington
# Processing Record 29 of Set 11 | poya
# Processing Record 30 of Set 11 | rabo de peixe
# Processing Record 31 of Set 11 | cacu
# Processing Record 32 of Set 11 | kaeo
# Processing Record 33 of Set 11 | teya
# Processing Record 34 of Set 11 | bandarbeyla
# Processing Record 35 of Set 11 | auki
# Processing Record 36 of Set 11 | shizunai
# Processing Record 37 of Set 11 | ziro
# Processing Record 38 of Set 11 | ahipara
# Processing Record 39 of Set 11 | qostanay
# Processing Record 40 of Set 11 | omboue
# Processing Record 41 of Set 11 | naze
# Processing Record 42 of Set 11 | buraydah
# Processing Record 43 of Set 11 | nedjo
# Processing Record 44 of Set 11 | samana
# Processing Record 45 of Set 11 | alofi
# Processing Record 46 of Set 11 | mount gambier
# Processing Record 47 of Set 11 | whitehorse
# Processing Record 48 of Set 11 | paradwip
# City not found. Skipping...
# Processing Record 49 of Set 11 | ikot ekpene
# Processing Record 50 of Set 11 | codrington
# Processing Record 1 of Set 12 | jamnah
# City not found. Skipping...
# Processing Record 2 of Set 12 | qaqortoq
# Processing Record 3 of Set 12 | talaya
# Processing Record 4 of Set 12 | adeje
# Processing Record 5 of Set 12 | caravelas
# Processing Record 6 of Set 12 | nabire
# Processing Record 7 of Set 12 | vanimo
# Processing Record 8 of Set 12 | havelock
# Processing Record 9 of Set 12 | jaisalmer
# Processing Record 10 of Set 12 | libreville
# Processing Record 11 of Set 12 | qesarya
# Processing Record 12 of Set 12 | maraa
# Processing Record 13 of Set 12 | kangalassy
# Processing Record 14 of Set 12 | honningsvag
# Processing Record 15 of Set 12 | bazarnyye mataki
# Processing Record 16 of Set 12 | hofn
# Processing Record 17 of Set 12 | matipo
# Processing Record 18 of Set 12 | beringovskiy
# Processing Record 19 of Set 12 | leningradskiy
# Processing Record 20 of Set 12 | saint-georges
# Processing Record 21 of Set 12 | urengoy
# Processing Record 22 of Set 12 | nsanje
# Processing Record 23 of Set 12 | toledo
# Processing Record 24 of Set 12 | shinpokh
# Processing Record 25 of Set 12 | russell
# Processing Record 26 of Set 12 | mahibadhoo
# Processing Record 27 of Set 12 | ambalavao
# Processing Record 28 of Set 12 | andarab
# City not found. Skipping...
# Processing Record 29 of Set 12 | pochutla
# Processing Record 30 of Set 12 | koygorodok
# Processing Record 31 of Set 12 | yuncheng
# Processing Record 32 of Set 12 | two rivers
# Processing Record 33 of Set 12 | srednekolymsk
# Processing Record 34 of Set 12 | formosa do rio preto
# Processing Record 35 of Set 12 | berdigestyakh
# Processing Record 36 of Set 12 | andenes
# Processing Record 37 of Set 12 | serro
# Processing Record 38 of Set 12 | waverly
# Processing Record 39 of Set 12 | mozarlandia
# Processing Record 40 of Set 12 | samusu
# City not found. Skipping...
# Processing Record 41 of Set 12 | grand river south east
# City not found. Skipping...
# Processing Record 42 of Set 12 | osmena
# Processing Record 43 of Set 12 | lalomanu
# City not found. Skipping...
# Processing Record 44 of Set 12 | skalistyy
# City not found. Skipping...
# Processing Record 45 of Set 12 | lucea
# Processing Record 46 of Set 12 | banjar
# Processing Record 47 of Set 12 | qujing
# Processing Record 48 of Set 12 | aksu
# Processing Record 49 of Set 12 | santa ana
# Processing Record 50 of Set 12 | puerto madryn
# Processing Record 1 of Set 13 | clarence town
# Processing Record 2 of Set 13 | mkokotoni
# Processing Record 3 of Set 13 | wulanhaote
# City not found. Skipping...
# Processing Record 4 of Set 13 | zheleznodorozhnyy
# Processing Record 5 of Set 13 | rincon
# Processing Record 6 of Set 13 | leh
# Processing Record 7 of Set 13 | belturbet
# Processing Record 8 of Set 13 | santa cruz
# Processing Record 9 of Set 13 | bahia de caraquez
# Processing Record 10 of Set 13 | wainwright
# Processing Record 11 of Set 13 | alugan
# Processing Record 12 of Set 13 | xuddur
# Processing Record 13 of Set 13 | perelyub
# Processing Record 14 of Set 13 | kiunga
# Processing Record 15 of Set 13 | impfondo
# Processing Record 16 of Set 13 | tynda
# Processing Record 17 of Set 13 | taltal
# Processing Record 18 of Set 13 | usinsk
# Processing Record 19 of Set 13 | huautla
# Processing Record 20 of Set 13 | mecca
# Processing Record 21 of Set 13 | muncar
# Processing Record 22 of Set 13 | jabiru
# City not found. Skipping...
# Processing Record 23 of Set 13 | canmore
# Processing Record 24 of Set 13 | pastavy
# Processing Record 25 of Set 13 | erenhot
# Processing Record 26 of Set 13 | pareora
# Processing Record 27 of Set 13 | novo aripuana
# Processing Record 28 of Set 13 | oksfjord
# Processing Record 29 of Set 13 | tonota
# Processing Record 30 of Set 13 | mubi
# Processing Record 31 of Set 13 | ahuimanu
# Processing Record 32 of Set 13 | binzhou
# Processing Record 33 of Set 13 | kushima
# Processing Record 34 of Set 13 | vanavara
# Processing Record 35 of Set 13 | marsabit
# Processing Record 36 of Set 13 | guarapari
# Processing Record 37 of Set 13 | witrivier
# City not found. Skipping...
# Processing Record 38 of Set 13 | portland
# Processing Record 39 of Set 13 | la palma
# Processing Record 40 of Set 13 | khandyga
# Processing Record 41 of Set 13 | hobe sound
# Processing Record 42 of Set 13 | surt
# Processing Record 43 of Set 13 | promyshlennaya
# Processing Record 44 of Set 13 | senanga
# Processing Record 45 of Set 13 | corbelia
# Processing Record 46 of Set 13 | santa marta de tormes
# Processing Record 47 of Set 13 | studenicani
# City not found. Skipping...
# Processing Record 48 of Set 13 | shingu
# Processing Record 49 of Set 13 | ambilobe
# Processing Record 50 of Set 13 | minnedosa
# Processing Record 1 of Set 14 | cairns
# Processing Record 2 of Set 14 | dois vizinhos
# Processing Record 3 of Set 14 | trebisacce
# Processing Record 4 of Set 14 | boffa
# Processing Record 5 of Set 14 | tigre
# Processing Record 6 of Set 14 | biak
# Processing Record 7 of Set 14 | newark
# Processing Record 8 of Set 14 | liwale
# Processing Record 9 of Set 14 | port macquarie
# Processing Record 10 of Set 14 | ranong
# Processing Record 11 of Set 14 | kashary
# Processing Record 12 of Set 14 | marfino
# Processing Record 13 of Set 14 | udachnyy
# Processing Record 14 of Set 14 | maceio
# Processing Record 15 of Set 14 | rundu
# Processing Record 16 of Set 14 | college
# Processing Record 17 of Set 14 | jiuquan
# Processing Record 18 of Set 14 | conde
# Processing Record 19 of Set 14 | balikpapan
# Processing Record 20 of Set 14 | le passage
# Processing Record 21 of Set 14 | husavik
# Processing Record 22 of Set 14 | miri
# Processing Record 23 of Set 14 | neryungri
# Processing Record 24 of Set 14 | pacifica
# Processing Record 25 of Set 14 | khandbari
# Processing Record 26 of Set 14 | kholtoson
# Processing Record 27 of Set 14 | zabol
# Processing Record 28 of Set 14 | zhangjiakou
# Processing Record 29 of Set 14 | sakaiminato
# Processing Record 30 of Set 14 | front royal
# Processing Record 31 of Set 14 | egvekinot
# Processing Record 32 of Set 14 | sur
# Processing Record 33 of Set 14 | dicabisagan
# Processing Record 34 of Set 14 | cameta
# Processing Record 35 of Set 14 | shevchenkove
# Processing Record 36 of Set 14 | talcahuano
# Processing Record 37 of Set 14 | flinders
# Processing Record 38 of Set 14 | tiznit
# Processing Record 39 of Set 14 | bogotol
# Processing Record 40 of Set 14 | dunedin
# Processing Record 41 of Set 14 | graham
# Processing Record 42 of Set 14 | laguna
# Processing Record 43 of Set 14 | gazojak
# Processing Record 44 of Set 14 | portage
# Processing Record 45 of Set 14 | general roca
# Processing Record 46 of Set 14 | clarksburg
# Processing Record 47 of Set 14 | greytown
# Processing Record 48 of Set 14 | stari bohorodchany
# Processing Record 49 of Set 14 | unhel
# Processing Record 50 of Set 14 | cumaribo
# City not found. Skipping...
# Processing Record 1 of Set 15 | gat
# Processing Record 2 of Set 15 | nantai
# Processing Record 3 of Set 15 | svetlyy
# Processing Record 4 of Set 15 | strezhevoy
# Processing Record 5 of Set 15 | priboj
# Processing Record 6 of Set 15 | playa vicente
# Processing Record 7 of Set 15 | balclutha
# Processing Record 8 of Set 15 | great falls
# Processing Record 9 of Set 15 | ialibu
# Processing Record 10 of Set 15 | vanderhoof
# Processing Record 11 of Set 15 | santa vitoria do palmar
# Processing Record 12 of Set 15 | gao
# Processing Record 13 of Set 15 | westport
# Processing Record 14 of Set 15 | whitecourt
# Processing Record 15 of Set 15 | keti bandar
# Processing Record 16 of Set 15 | darnah
# Processing Record 17 of Set 15 | zhurivka
# Processing Record 18 of Set 15 | cotonou
# Processing Record 19 of Set 15 | mandalgovi
# Processing Record 20 of Set 15 | pushkino
# Processing Record 21 of Set 15 | parnamirim
# Processing Record 22 of Set 15 | harlingen
# Processing Record 23 of Set 15 | cukai
# Processing Record 24 of Set 15 | kresek
# Processing Record 25 of Set 15 | mayo
# Processing Record 26 of Set 15 | fairbanks
# Processing Record 27 of Set 15 | vuktyl
# Processing Record 28 of Set 15 | phuket
# Processing Record 29 of Set 15 | muzhi
# Processing Record 30 of Set 15 | poronaysk
# Processing Record 31 of Set 15 | mugur-aksy
# Processing Record 32 of Set 15 | bijapur
# Processing Record 33 of Set 15 | le port
# Processing Record 34 of Set 15 | san cristobal
# Processing Record 35 of Set 15 | mackay
# Processing Record 36 of Set 15 | chhuikhadan
# Processing Record 37 of Set 15 | blyth
# Processing Record 38 of Set 15 | halifax
# Processing Record 39 of Set 15 | buala
# Processing Record 40 of Set 15 | jijiga
# Processing Record 41 of Set 15 | bedford
# Processing Record 42 of Set 15 | esfahan
# Processing Record 43 of Set 15 | imbituba
# Processing Record 44 of Set 15 | general pico
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Reorder the column names
new_column_order=["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df=city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Narsaq      GL  60.9167  -46.0500     46.62        95         100
# 1         Madimba      TZ -10.4000   40.3333     68.74        86           8
# 2          Lompoc      US  34.6391 -120.4579     70.09        81           1
# 3          Namibe      AO -15.1961   12.1522     65.68        86          21
# 4     New Norfolk      AU -42.7826  147.0587     55.89        64          98
# 5          Kodiak      US  57.7900 -152.4072     54.91        76          90
# 6      Georgetown      MY   5.4112  100.3354     89.55        68          20
# 7  Mount Pleasant      US  32.7941  -79.8626     79.99        90          20
# 8      Hambantota      LK   6.1241   81.1185     86.34        74          20
# 9        Celestun      MX  20.8667  -90.4000     77.50        89          64
#
#    Wind Speed Current Description
# 0        2.55          light rain
# 1        8.57           clear sky
# 2       10.36           clear sky
# 3        8.57          few clouds
# 4        1.07     overcast clouds
# 5       10.36     overcast clouds
# 6        1.99          few clouds
# 7        3.00                mist
# 8       14.97          few clouds
# 9       13.47       broken clouds

# %%
# Export as a csv file
city_data_df.to_csv("WeatherPy_Database.csv")
